# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
# mkdir: cannot create directory ‘/tmp/Multimodal_IMDB_dataset’: File exists
#               0   0%    0.00kB/s    0:00:00 (xfr#0, to-chk=0/7897)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/tmp/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [64, 64])
    return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

posters_train_ds = (
    list_posters_train_ds
    .shuffle(1000)
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(64)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .prefetch(tf.data.AUTOTUNE)
)

posters_valid_ds = (
    list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(64)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

overviews_train_ds = (
    list_overviews_train_ds
    .batch(64)
    .prefetch(tf.data.AUTOTUNE)
)

overviews_valid_ds = (
    list_overviews_valid_ds
    .batch(64)
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

VOCAB_SIZE = 10000

encoder = tf.keras.layers.TextVectorization(max_tokens=VOCAB_SIZE)
encoder.adapt(overviews_train_ds.map(lambda text, label: text))

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.

print(encoder.get_vocabulary()[:200])
# Out:
# ['', '[UNK]', np.str_('a'), np.str_('the'), np.str_('to'), np.str_('of'), np.str_('and'), np.str_('in'), np.str_('his'), np.str_('is'), np.str_('an'), np.str_('with'), np.str_('her'), np.str_('for'), np.str_('on'), np.str_('he'), np.str_('their'), np.str_('who'), np.str_('by'), np.str_('from'), np.str_('when'), np.str_('as'), np.str_('that'), np.str_('after'), np.str_('young'), np.str_('life'), np.str_('they'), np.str_('at'), np.str_('man'), np.str_('him'), np.str_('new'), np.str_('two'), np.str_('but'), np.str_('are'), np.str_('into'), np.str_('has'), np.str_('up'), np.str_('she'), np.str_('woman'), np.str_('one'), np.str_('family'), np.str_('out'), np.str_('love'), np.str_('find'), np.str_('must'), np.str_('be'), np.str_('friends'), np.str_('world'), np.str_('finds'), np.str_('it'), np.str_('school'), np.str_('story'), np.str_('them'), np.str_('about'), np.str_('where'), np.str_('group'), np.str_('while'), np.str_('father'), np.str_('have'), np.str_('years'), np.str_('girl'), np.str_('lives'), np.str_('war'), np.str_('wife'), np.str_('town'), np.str_('becomes'), np.str_('three'), np.str_('help'), np.str_('city'), np.str_('get'), np.str_('boy'), np.str_('home'), np.str_('during'), np.str_('all'), np.str_('gets'), np.str_('back'), np.str_('himself'), np.str_('son'), np.str_('high'), np.str_('team'), np.str_('only'), np.str_('which'), np.str_('york'), np.str_('between'), np.str_('american'), np.str_('murder'), np.str_('takes'), np.str_('against'), np.str_('other'), np.str_('time'), np.str_('police'), np.str_('its'), np.str_('tries'), np.str_('own'), np.str_('mother'), np.str_('down'), np.str_('daughter'), np.str_('small'), np.str_('order'), np.str_('former'), np.str_('friend'), np.str_('being'), np.str_('this'), np.str_('can'), np.str_('before'), np.str_('become'), np.str_('old'), np.str_('save'), np.str_('falls'), np.str_('was'), np.str_('set'), np.str_('college'), np.str_('over'), np.str_('death'), np.str_('will'), np.str_('together'), np.str_('goes'), np.str_('take'), np.str_('agent'), np.str_('not'), np.str_('off'), np.str_('killer'), np.str_('go'), np.str_('through'), np.str_('husband'), np.str_('first'), np.str_('each'), np.str_('mysterious'), np.str_('meets'), np.str_('way'), np.str_('couple'), np.str_('more'), np.str_('begins'), np.str_('relationship'), np.str_('people'), np.str_('returns'), np.str_('brother'), np.str_('make'), np.str_('job'), np.str_('work'), np.str_('what'), np.str_('hes'), np.str_('stop'), np.str_('now'), np.str_('living'), np.str_('us'), np.str_('discovers'), np.str_('day'), np.str_('drug'), np.str_('been'), np.str_('secret'), np.str_('forced'), np.str_('local'), np.str_('parents'), np.str_('best'), np.str_('married'), np.str_('just'), np.str_('house'), np.str_('trying'), np.str_('cop'), np.str_('student'), np.str_('men'), np.str_('evil'), np.str_('comes'), np.str_('turns'), np.str_('soon'), np.str_('past'), np.str_('most'), np.str_('movie'), np.str_('film'), np.str_('detective'), np.str_('women'), np.str_('so'), np.str_('whose'), np.str_('discover'), np.str_('true'), np.str_('four'), np.str_('teenage'), np.str_('or'), np.str_('wants'), np.str_('sent'), np.str_('officer'), np.str_('earth'), np.str_('brothers'), np.str_('than'), np.str_('black'), np.str_('try'), np.str_('fight'), np.str_('away'), np.str_('around'), np.str_('run'), np.str_('prison'), np.str_('crime'), np.str_('another'), np.str_('then'), np.str_('star'), np.str_('live'), np.str_('children'), np.str_('themselves'), np.str_('series')]

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
    # Input layer
    inputs = Input(shape=(64, 64, 3), name='Input')

    # Conv0 block
    x = Conv2D(16, (3, 3), strides=2, padding='same', activation='relu', name='Conv0')(inputs)
    x = Dropout(0.2, name='Drop1')(x)

    # Conv1 and Conv2 block
    x = Conv2D(32, (3, 3), padding='same', activation='relu', name='Conv1')(x)
    x = Conv2D(32, (3, 3), padding='same', activation='relu', name='Conv2')(x)
    x = Dropout(0.2, name='Drop2')(x)
    x = MaxPooling2D((2, 2), strides=2, name='Pool1')(x)

    # Conv3 and Conv4 block
    x = Conv2D(64, (3, 3), padding='same', activation='relu', name='Conv3')(x)
    x = Conv2D(64, (3, 3), padding='same', activation='relu', name='Conv4')(x)
    x = Dropout(0.2, name='Drop3')(x)
    x = MaxPooling2D((2, 2), strides=2, name='Pool2')(x)

    # Conv5 and Conv6 block
    x = Conv2D(128, (3, 3), padding='same', activation='relu', name='Conv5')(x)
    x = Conv2D(128, (3, 3), padding='same', activation='relu', name='Conv6')(x)
    x = Dropout(0.2, name='Drop4')(x)
    x = MaxPooling2D((2, 2), strides=2, name='Pool3')(x)

    # Flatten and dense layers
    x = Flatten(name='Flat')(x)
    x = Dense(1024, activation='relu', name='FC1')(x)
    x = Dropout(0.5, name='Drop5')(x)
    x = Dense(1024, activation='relu', name='FC2')(x)
    x = Dropout(0.5, name='Drop6')(x)

    # Output layer
    outputs = Dense(25, activation='sigmoid', name='Output')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.

cnn_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv0 (Conv2D)                  │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop1 (Dropout)                 │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1 (Conv2D)                  │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2 (Conv2D)                  │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop2 (Dropout)                 │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool1 (MaxPooling2D)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv4 (Conv2D)                  │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop3 (Dropout)                 │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool2 (MaxPooling2D)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv5 (Conv2D)                  │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv6 (Conv2D)                  │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop4 (Dropout)                 │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3 (MaxPooling2D)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flat (Flatten)                  │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC1 (Dense)                     │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop5 (Dropout)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC2 (Dense)                     │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop6 (Dropout)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 25)             │        25,625 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[
        Precision(name='precision'),
        Recall(name='recall')
    ]
)

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

embedder = tf.keras.layers.Embedding(
    input_dim=encoder.vocabulary_size(),
    output_dim=256,
    mask_zero=True
)

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = tf.keras.Sequential([
    encoder,
    embedder,
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, dropout=0.5, recurrent_dropout=0.2, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.8),
    tf.keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.

lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization_1            │ (None, None)           │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, None, 256)      │     2,560,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, None, 512)      │     1,050,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 256)            │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

lstm_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[
        Precision(name='precision'),
        Recall(name='recall')
    ]
    )

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    filepath=checkpoint_cnn_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

checkpoint_lstm_callback = ModelCheckpoint(
    filepath=checkpoint_lstm_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.01))

lr_callback = LearningRateScheduler(scheduler, verbose=1)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    posters_train_ds,
    validation_data=posters_valid_ds,
    epochs=40,
    callbacks=[checkpoint_cnn_callback, lr_callback]
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 684ms/step - loss: 0.4198 - precision: 0.3149 - recall: 0.3315
# Epoch 1: val_loss improved from inf to 0.33127, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 683ms/step - loss: 0.2202 - precision: 0.6396 - recall: 0.2827 - val_loss: 0.2500 - val_precision: 0.5717 - val_recall: 0.2259 - learning_rate: 8.8692e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 8.78095452208072e-05.
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - loss: 0.2201 - precision: 0.6447 - recall: 0.2867
# Epoch 23: val_loss did not improve from 0.24873
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 668ms/step - loss: 0.2201 - precision: 0.6447 - recall: 0.2867 - val_loss: 0.2494 - val_precision: 0.5719 - val_recall: 0.2279 - learning_rate: 8.7810e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 8.69358264026232e-05.
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - loss: 0.2202 - precision: 0.6411 - recall: 0.2860
# Epoch 24: val_loss improved from 0.24873 to 0.24824, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 659ms/step - loss: 0.2202 - precision: 0.6412 - recall: 0.2861 - val_loss: 0.2482 - val_precision: 0.5759 - val_recall: 0.2249 - learning_rate: 8.6936e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 8.607080235378817e-05.
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - loss: 0.2185 - precision: 0.6473 - recall: 0.2876
# Epoch 25: val_loss improved from 0.24824 to 0.24536, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 666ms/step - loss: 0.2185 - precision: 0.6474 - recall: 0.2876 - val_loss: 0.2454 - val_precision: 0.5837 - val_recall: 0.2266 - learning_rate: 8.6071e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 8.521438576281071e-05.
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - loss: 0.2182 - precision: 0.6462 - recall: 0.2899
# Epoch 26: val_loss did not improve from 0.24536
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 54s 678ms/step - loss: 0.2182 - precision: 0.6463 - recall: 0.2899 - val_loss: 0.2460 - val_precision: 0.5772 - val_recall: 0.2279 - learning_rate: 8.5214e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 8.436648931819946e-05.
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - loss: 0.2179 - precision: 0.6448 - recall: 0.2853
# Epoch 27: val_loss improved from 0.24536 to 0.24299, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 52s 645ms/step - loss: 0.2179 - precision: 0.6449 - recall: 0.2854 - val_loss: 0.2430 - val_precision: 0.5826 - val_recall: 0.2326 - learning_rate: 8.4366e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 8.352702570846304e-05.
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2159 - precision: 0.6517 - recall: 0.2910
# Epoch 28: val_loss did not improve from 0.24299
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 664ms/step - loss: 0.2159 - precision: 0.6518 - recall: 0.2911 - val_loss: 0.2476 - val_precision: 0.5710 - val_recall: 0.2279 - learning_rate: 8.3527e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 8.269591489806771e-05.
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - loss: 0.2163 - precision: 0.6553 - recall: 0.2972
# Epoch 29: val_loss did not improve from 0.24299
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 662ms/step - loss: 0.2163 - precision: 0.6554 - recall: 0.2972 - val_loss: 0.2438 - val_precision: 0.5845 - val_recall: 0.2269 - learning_rate: 8.2696e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 8.187307685147971e-05.
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - loss: 0.2159 - precision: 0.6504 - recall: 0.2880
# Epoch 30: val_loss improved from 0.24299 to 0.24212, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 54s 679ms/step - loss: 0.2158 - precision: 0.6505 - recall: 0.2881 - val_loss: 0.2421 - val_precision: 0.5875 - val_recall: 0.2326 - learning_rate: 8.1873e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 8.105842425720766e-05.
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - loss: 0.2146 - precision: 0.6615 - recall: 0.2973
# Epoch 31: val_loss did not improve from 0.24212
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 51s 642ms/step - loss: 0.2146 - precision: 0.6616 - recall: 0.2973 - val_loss: 0.2445 - val_precision: 0.5810 - val_recall: 0.2223 - learning_rate: 8.1058e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 8.025187707971781e-05.
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2148 - precision: 0.6612 - recall: 0.2921
# Epoch 32: val_loss did not improve from 0.24212
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 664ms/step - loss: 0.2148 - precision: 0.6613 - recall: 0.2922 - val_loss: 0.2434 - val_precision: 0.5910 - val_recall: 0.2283 - learning_rate: 8.0252e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 7.945335528347641e-05.
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 631ms/step - loss: 0.2133 - precision: 0.6630 - recall: 0.2945
# Epoch 33: val_loss did not improve from 0.24212
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 663ms/step - loss: 0.2133 - precision: 0.6631 - recall: 0.2946 - val_loss: 0.2436 - val_precision: 0.5823 - val_recall: 0.2263 - learning_rate: 7.9453e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.86627788329497e-05.
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2129 - precision: 0.6628 - recall: 0.2965
# Epoch 34: val_loss improved from 0.24212 to 0.24200, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 664ms/step - loss: 0.2128 - precision: 0.6629 - recall: 0.2966 - val_loss: 0.2420 - val_precision: 0.5998 - val_recall: 0.2283 - learning_rate: 7.8663e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 7.788007496856153e-05.
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - loss: 0.2118 - precision: 0.6733 - recall: 0.3030
# Epoch 35: val_loss did not improve from 0.24200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 54s 676ms/step - loss: 0.2118 - precision: 0.6733 - recall: 0.3030 - val_loss: 0.2439 - val_precision: 0.5863 - val_recall: 0.2309 - learning_rate: 7.7880e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.710515637882054e-05.
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - loss: 0.2113 - precision: 0.6723 - recall: 0.3046
# Epoch 36: val_loss did not improve from 0.24200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 51s 641ms/step - loss: 0.2112 - precision: 0.6724 - recall: 0.3047 - val_loss: 0.2422 - val_precision: 0.5920 - val_recall: 0.2316 - learning_rate: 7.7105e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.633795030415058e-05.
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2098 - precision: 0.6766 - recall: 0.3047
# Epoch 37: val_loss did not improve from 0.24200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 664ms/step - loss: 0.2097 - precision: 0.6766 - recall: 0.3047 - val_loss: 0.2424 - val_precision: 0.5909 - val_recall: 0.2296 - learning_rate: 7.6338e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.55783767090179e-05.
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2092 - precision: 0.6745 - recall: 0.3094
# Epoch 38: val_loss improved from 0.24200 to 0.23955, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 666ms/step - loss: 0.2092 - precision: 0.6745 - recall: 0.3094 - val_loss: 0.2396 - val_precision: 0.5839 - val_recall: 0.2343 - learning_rate: 7.5578e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.482636283384636e-05.
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - loss: 0.2079 - precision: 0.6761 - recall: 0.3121
# Epoch 39: val_loss did not improve from 0.23955
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 54s 677ms/step - loss: 0.2079 - precision: 0.6762 - recall: 0.3121 - val_loss: 0.2402 - val_precision: 0.6069 - val_recall: 0.2393 - learning_rate: 7.4826e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.40818286431022e-05.
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - loss: 0.2073 - precision: 0.6838 - recall: 0.3187
# Epoch 40: val_loss did not improve from 0.23955
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 51s 642ms/step - loss: 0.2073 - precision: 0.6839 - recall: 0.3188 - val_loss: 0.2409 - val_precision: 0.5880 - val_recall: 0.2316 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.
lstm_history = lstm_model.fit(
    overviews_train_ds,
    validation_data=overviews_valid_ds,
    epochs=20,
    callbacks=[checkpoint_lstm_callback, lr_callback]
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.6680 - precision: 0.1002 - recall: 0.3790
# Epoch 1: val_loss improved from inf to 0.37221, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - loss: 0.6674 - precision: 0.1003 - recall: 0.3784 - val_loss: 0.3722 - val_precision: 0.5058 - val_recall: 0.1896 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.4799 - precision: 0.1595 - recall: 0.2894
# Epoch 2: val_loss improved from 0.37221 to 0.30462, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - loss: 0.4797 - precision: 0.1596 - recall: 0.2894 - val_loss: 0.3046 - val_precision: 0.5158 - val_recall: 0.2116 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.4276 - precision: 0.1878 - recall: 0.2694
# Epoch 3: val_loss improved from 0.30462 to 0.27852, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - loss: 0.4275 - precision: 0.1879 - recall: 0.2694 - val_loss: 0.2785 - val_precision: 0.5203 - val_recall: 0.2183 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3953 - precision: 0.2196 - recall: 0.2547
# Epoch 4: val_loss improved from 0.27852 to 0.26470, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - loss: 0.3952 - precision: 0.2196 - recall: 0.2546 - val_loss: 0.2647 - val_precision: 0.5214 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3718 - precision: 0.2530 - recall: 0.2560
# Epoch 5: val_loss improved from 0.26470 to 0.25624, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - loss: 0.3717 - precision: 0.2531 - recall: 0.2559 - val_loss: 0.2562 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3513 - precision: 0.2737 - recall: 0.2421
# Epoch 6: val_loss improved from 0.25624 to 0.25194, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - loss: 0.3512 - precision: 0.2738 - recall: 0.2420 - val_loss: 0.2519 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3364 - precision: 0.3105 - recall: 0.2377
# Epoch 7: val_loss improved from 0.25194 to 0.24770, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - loss: 0.3363 - precision: 0.3106 - recall: 0.2377 - val_loss: 0.2477 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3259 - precision: 0.3363 - recall: 0.2439
# Epoch 8: val_loss improved from 0.24770 to 0.24551, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - loss: 0.3258 - precision: 0.3363 - recall: 0.2438 - val_loss: 0.2455 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3193 - precision: 0.3424 - recall: 0.2352
# Epoch 9: val_loss improved from 0.24551 to 0.24414, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - loss: 0.3193 - precision: 0.3424 - recall: 0.2352 - val_loss: 0.2441 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3116 - precision: 0.3562 - recall: 0.2175
# Epoch 10: val_loss improved from 0.24414 to 0.24281, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - loss: 0.3116 - precision: 0.3562 - recall: 0.2175 - val_loss: 0.2428 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.900498116621748e-05.
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3039 - precision: 0.3747 - recall: 0.2230
# Epoch 11: val_loss improved from 0.24281 to 0.24137, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - loss: 0.3038 - precision: 0.3747 - recall: 0.2230 - val_loss: 0.2414 - val_precision: 0.5209 - val_recall: 0.2196 - learning_rate: 9.9005e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.801986743696034e-05.
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2997 - precision: 0.3870 - recall: 0.2207
# Epoch 12: val_loss improved from 0.24137 to 0.24011, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - loss: 0.2997 - precision: 0.3870 - recall: 0.2206 - val_loss: 0.2401 - val_precision: 0.5247 - val_recall: 0.2193 - learning_rate: 9.8020e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.704455442260951e-05.
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2941 - precision: 0.3990 - recall: 0.2197
# Epoch 13: val_loss improved from 0.24011 to 0.23851, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - loss: 0.2941 - precision: 0.3990 - recall: 0.2197 - val_loss: 0.2385 - val_precision: 0.5248 - val_recall: 0.2189 - learning_rate: 9.7045e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.6078947535716e-05.
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2888 - precision: 0.4300 - recall: 0.2326
# Epoch 14: val_loss improved from 0.23851 to 0.23575, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - loss: 0.2888 - precision: 0.4300 - recall: 0.2326 - val_loss: 0.2358 - val_precision: 0.5691 - val_recall: 0.1976 - learning_rate: 9.6079e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.512294491287321e-05.
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2817 - precision: 0.4313 - recall: 0.2302
# Epoch 15: val_loss improved from 0.23575 to 0.23252, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - loss: 0.2816 - precision: 0.4314 - recall: 0.2302 - val_loss: 0.2325 - val_precision: 0.5947 - val_recall: 0.1863 - learning_rate: 9.5123e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.417645924258977e-05.
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2756 - precision: 0.4593 - recall: 0.2360
# Epoch 16: val_loss improved from 0.23252 to 0.23026, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 0.2756 - precision: 0.4593 - recall: 0.2361 - val_loss: 0.2303 - val_precision: 0.6047 - val_recall: 0.1876 - learning_rate: 9.4176e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.323938866145909e-05.
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2708 - precision: 0.4759 - recall: 0.2512
# Epoch 17: val_loss improved from 0.23026 to 0.22879, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 0.2708 - precision: 0.4759 - recall: 0.2512 - val_loss: 0.2288 - val_precision: 0.5932 - val_recall: 0.2483 - learning_rate: 9.3239e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.231163858203217e-05.
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2660 - precision: 0.4934 - recall: 0.2724
# Epoch 18: val_loss improved from 0.22879 to 0.22698, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 0.2660 - precision: 0.4934 - recall: 0.2723 - val_loss: 0.2270 - val_precision: 0.5960 - val_recall: 0.2463 - learning_rate: 9.2312e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.139312169281766e-05.
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2627 - precision: 0.5007 - recall: 0.2611
# Epoch 19: val_loss improved from 0.22698 to 0.22687, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 0.2627 - precision: 0.5007 - recall: 0.2612 - val_loss: 0.2269 - val_precision: 0.5827 - val_recall: 0.2712 - learning_rate: 9.1393e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.048374340636656e-05.
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2607 - precision: 0.5097 - recall: 0.2693
# Epoch 20: val_loss improved from 0.22687 to 0.22624, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - loss: 0.2607 - precision: 0.5097 - recall: 0.2693 - val_loss: 0.2262 - val_precision: 0.5898 - val_recall: 0.2726 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('CNN Loss')

plt.subplot(1, 2, 2)
plt.plot(cnn_history.history['precision'], label='Training Precision')
plt.plot(cnn_history.history['val_precision'], label='Validation Precision')
plt.plot(cnn_history.history['recall'], label='Training Recall')
plt.plot(cnn_history.history['val_recall'], label='Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.legend()
plt.title('CNN Metrics')
plt.tight_layout()
plt.show()

# Load best CNN weights and evaluate per-class performance
cnn_model.load_weights(checkpoint_cnn_filepath)
y_pred_cnn = cnn_model.predict(posters_valid_ds)
y_pred_cnn_bin = (y_pred_cnn > 0.5).astype(int)

from sklearn.metrics import precision_score, recall_score
precision_cnn = precision_score(labels_test, y_pred_cnn_bin, average=None)
recall_cnn = recall_score(labels_test, y_pred_cnn_bin, average=None)

plt.figure(figsize=(20, 6))
plt.bar(genres, precision_cnn, alpha=0.6, label='Precision')
plt.bar(genres, recall_cnn, alpha=0.6, label='Recall')
plt.xticks(rotation=90)
plt.ylabel('Score')
plt.title('CNN Per-Class Precision and Recall')
plt.legend()
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i

# Plot LSTM training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(lstm_history.history['loss'], label='Training Loss')
plt.plot(lstm_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('LSTM Loss')

plt.subplot(1, 2, 2)
plt.plot(lstm_history.history['precision'], label='Training Precision')
plt.plot(lstm_history.history['val_precision'], label='Validation Precision')
plt.plot(lstm_history.history['recall'], label='Training Recall')
plt.plot(lstm_history.history['val_recall'], label='Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.legend()
plt.title('LSTM Metrics')
plt.tight_layout()
plt.show()

# Load best LSTM weights and evaluate per-class performance
lstm_model.load_weights(checkpoint_lstm_filepath)
y_pred_lstm = lstm_model.predict(overviews_valid_ds)
y_pred_lstm_bin = (y_pred_lstm > 0.5).astype(int)

precision_lstm = precision_score(labels_test, y_pred_lstm_bin, average=None)
recall_lstm = recall_score(labels_test, y_pred_lstm_bin, average=None)

plt.figure(figsize=(20, 6))
plt.bar(genres, precision_lstm, alpha=0.6, label='Precision')
plt.bar(genres, recall_lstm, alpha=0.6, label='Recall')
plt.xticks(rotation=90)
plt.ylabel('Score')
plt.title('LSTM Per-Class Precision and Recall')
plt.legend()
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 479ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c

# Load best weights
cnn_model.load_weights(checkpoint_cnn_filepath)
lstm_model.load_weights(checkpoint_lstm_filepath)

# Select example films
sample_indices = [0, 5, 10]
for idx in sample_indices:
    row = data_test.iloc[idx]
    img_id = row['Id']
    overview = row['Overview']
    true_genres = row['Genre'].split(', ')

    # Load and process poster
    img_path = f"/tmp/Multimodal_IMDB_dataset/Images/{img_id}.jpg"
    image = tf.io.read_file(img_path)
    image = tf.io.decode_jpeg(image)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [64, 64])

    # CNN prediction
    cnn_pred = cnn_model.predict(tf.expand_dims(image, 0))[0]
    cnn_top3 = np.argsort(cnn_pred)[::-1][:3]

    # LSTM prediction
    lstm_pred = lstm_model.predict(tf.constant([overview]))[0]
    lstm_top3 = np.argsort(lstm_pred)[::-1][:3]

    # Plotting
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(image.numpy())
    plt.axis('off')
    plt.title(f'Poster: {img_id}')

    # Predictions
    plt.subplot(1, 2, 2)
    plt.axis('off')
    info_text = (
        f"True Genres: {', '.join(true_genres)}\n\n"
        f"CNN Predictions:\n"
        f"1. {genres[cnn_top3[0]]} ({cnn_pred[cnn_top3[0]]:.2f})\n"
        f"2. {genres[cnn_top3[1]]} ({cnn_pred[cnn_top3[1]]:.2f})\n"
        f"3. {genres[cnn_top3[2]]} ({cnn_pred[cnn_top3[2]]:.2f})\n\n"
        f"LSTM Predictions:\n"
        f"1. {genres[lstm_top3[0]]} ({lstm_pred[lstm_top3[0]]:.2f})\n"
        f"2. {genres[lstm_top3[1]]} ({lstm_pred[lstm_top3[1]]:.2f})\n"
        f"3. {genres[lstm_top3[2]]} ({lstm_pred[lstm_top3[2]]:.2f})"
    )
    plt.text(0, 0.5, info_text, fontsize=12)
    plt.tight_layout()
    plt.show()

    print(f"Overview:\n{overview}\n")
    print("------------------------------------------------------")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Overview:
# Dream-haunting Freddy Krueger returns once again to prowl the nightmares of Springwood's last surviving teenager, and of a woman whose personal connection to Krueger may mean his doom.
#
# ------------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Overview:
# A comedy about a psychiatrist whose number one patient is an insecure mob boss.
#
# ------------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Overview:
# Following Kick-Ass' heroics, other citizens are inspired to become masked crusaders. But Red Mist leads his own group of evil supervillains to get revenge, kill Kick-Ass and destroy everything he stands for.
#
# ------------------------------------------------------
